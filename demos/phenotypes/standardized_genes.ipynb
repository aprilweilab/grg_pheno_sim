# %%
import numpy as np
import pygrgl
import matplotlib.pyplot as plt 

from grg_pheno_sim.phenotype import sim_phenotypes
from grg_pheno_sim.model import grg_causal_mutation_model

# %%
# %%script bash --out /dev/null
# if [ ! -f test-200-samples.grg ]; then
#   grg construct -p 10 -t 2 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg
# fi

# %%
grg_1 = pygrgl.load_immutable_grg("test-200-samples.grg") #loading in a sample grg stored in the same directory

heritability = 0.33

phenotypes_standardized_genes = sim_phenotypes(grg_1, heritability=heritability, standardized=True)
# Out:
# The initial effect sizes are
#      mutation_id  effect_size  causal_mutation_id
# 0             43    -0.025149                   0
# 1             49    -0.002312                   0
# 2             54    -0.002987                   0
# 3             55     0.011793                   0
# 4             67     0.000544                   0
# ..           ...          ...                 ...
# 995        10798     0.001064                   0
# 996        10804     0.010454                   0
# 997        10844    -0.004421                   0
# 998        10860    -0.012756                   0
# 999        10888    -0.010870                   0
#
# [1000 rows x 3 columns]
# The genetic values of the individuals are
#      individual_id  genetic_value  causal_mutation_id
# 0                0      -0.451663                   0
# 1                1       0.113716                   0
# 2                2       0.105123                   0
# 3                3      -0.290751                   0
# 4                4      -0.104078                   0
# ..             ...            ...                 ...
# 195            195      -0.155053                   0
# 196            196      -0.132703                   0
# 197            197      -0.451707                   0
# 198            198      -0.321904                   0
# 199            199      -0.659460                   0
#
# [200 rows x 3 columns]
# The final phenotypes are
#      individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                0      -0.451663                   0             0.138776
# 1                1       0.113716                   0            -0.473635
# 2                2       0.105123                   0             0.341774
# 3                3      -0.290751                   0             0.428357
# 4                4      -0.104078                   0            -0.888550
# ..             ...            ...                 ...                  ...
# 195            195      -0.155053                   0            -0.407481
# 196            196      -0.132703                   0             0.292987
# 197            197      -0.451707                   0            -0.179713
# 198            198      -0.321904                   0            -0.002333
# 199            199      -0.659460                   0            -0.074436
#
#      phenotype
# 0    -0.312887
# 1    -0.359919
# 2     0.446897
# 3     0.137606
# 4    -0.992628
# ..         ...
# 195  -0.562534
# 196   0.160284
# 197  -0.631420
# 198  -0.324236
# 199  -0.733895
#
# [200 rows x 5 columns]

# %%
phenotypes_standardized_genes
# Out:
#      individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                0      -0.451663                   0             0.138776
# 1                1       0.113716                   0            -0.473635
# 2                2       0.105123                   0             0.341774
# 3                3      -0.290751                   0             0.428357
# 4                4      -0.104078                   0            -0.888550
# ..             ...            ...                 ...                  ...
# 195            195      -0.155053                   0            -0.407481
# 196            196      -0.132703                   0             0.292987
# 197            197      -0.451707                   0            -0.179713
# 198            198      -0.321904                   0            -0.002333
# 199            199      -0.659460                   0            -0.074436
#
#      phenotype
# 0    -0.312887
# 1    -0.359919
# 2     0.446897
# 3     0.137606
# 4    -0.992628
# ..         ...
# 195  -0.562534
# 196   0.160284
# 197  -0.631420
# 198  -0.324236
# 199  -0.733895
#
# [200 rows x 5 columns]
