# %% [markdown]
# This notebook performs phenotype simulation using standardized genetic effect sizes with the sim_phenotypes function, by setting the standardized parameter to True. The resultant dataframe from the output is also shown.

# %%
import numpy as np
import pygrgl
import matplotlib.pyplot as plt 

from grg_pheno_sim.phenotype import sim_phenotypes, sim_phenotypes_custom

# %% [markdown]
# The following command only serves the purpose of converting the VCF zip file into a GRG that will be used for the phenotype simulation. The bash script below will function as expected given the relative path for the source data file is accurate.

# %%
# %%script bash --out /dev/null
# if [ ! -f test-200-samples.grg ]; then
#   grg construct -p 10 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg
# fi

# %%
grg_1 = pygrgl.load_immutable_grg("test-200-samples.grg") #loading in a sample grg stored in the same directory

heritability = 0.33

phenotypes_standardized_genes = sim_phenotypes(grg_1, heritability=heritability, standardized=True)
# Out:
# The initial effect sizes are
#      mutation_id  effect_size  causal_mutation_id
# 0             43    -0.043778                   0
# 1             49    -0.004024                   0
# 2             54    -0.005199                   0
# 3             55     0.020529                   0
# 4             67     0.000948                   0
# ..           ...          ...                 ...
# 995        10798     0.001852                   0
# 996        10804     0.018198                   0
# 997        10844    -0.007695                   0
# 998        10860    -0.022206                   0
# 999        10888    -0.018921                   0
#
# [1000 rows x 3 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       1 grg_1 = pygrgl.load_immutable_grg("test-200-samples.grg") #loading in a sample grg stored in the same directory
#       3 heritability = 0.33
# ----> 5 phenotypes_standardized_genes = sim_phenotypes(grg_1, heritability=heritability, standardized=True)
#
# File ~/grg_pheno_sim/grg_pheno_sim/phenotype.py:111, in sim_phenotypes(grg, model, num_causal, random_seed, normalize_phenotype, normalize_genetic_values_before_noise, heritability, user_mean, user_cov, normalize_genetic_values_after, save_effect_output, effect_path, standardized_output, path, header, standardized)
#      73 """
#      74 Function to simulate phenotypes in one go by combining all intermittent stages.
#      75
#    (...)
#     107 `phenotype`
#     108 """
#     110 if standardized is True:
# --> 111     return sim_phenotypes_StdOp(
#     112         grg,
#     113         heritability,
#     114         num_causal,
#     115         random_seed,
#     116         save_effect_output,
#     117         effect_path,
#     118         standardized_output,
#     119         path,
#     120         header,
#     121     )
#     123 causal_mutation_df = sim_grg_causal_mutation(
#     124     grg, model=model, num_causal=num_causal, random_seed=random_seed
#     125 )
#     127 print("The initial effect sizes are ")
#
# File ~/grg_pheno_sim/grg_pheno_sim/phenotype.py:409, in sim_phenotypes_StdOp(grg, heritability, num_causal, random_seed, save_effect_output, effect_path, standardized_output, path, header)
#     406 beta_full[causal_sites] = causal_mutation_df["effect_size"].values
#     407 beta_full = beta_full.reshape(-1, 1)
#     408 individual_genetic_values = np.squeeze(
# --> 409     _SciPyStdXOperator(
#     410         grg, direction=pygrgl.TraversalDirection.UP, freqs=freqs, haploid=False
#     411     )._matmat(beta_full)
#     412 )
#     414 n_ind = grg.num_individuals
#     415 df = pd.DataFrame(
#     416     {
#     417         "individual_id": np.arange(n_ind, dtype=int),
#    (...)
#     420     }
#     421 )
#
# File ~/grg_pheno_sim/grg_pheno_sim/ops_scipy.py:113, in SciPyStdXOperator.__init__(self, grg, direction, freqs, haploid, dtype)
#      92 """
#      93 Construct a LinearOperator compatible with scipy's sparse linear algebra module.
#      94 Let X be the genotype matrix, as represented by the GRG, then this operator computes either
#    (...)
#     110 :type dtype: numpy.dtype
#     111 """
#     112 self.direction = direction
# --> 113 self.sample_count = grg.num_samples if haploid else grg.num_individuals
#     114 if self.direction == pygrgl.TraversalDirection.UP:
#     115     shape = (self.sample_count, grg.num_mutations)
#
# AttributeError: '_grgl.GRG' object has no attribute 'num_individuals'

# %%
phenotypes_standardized_genes
# Out:
#      individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                0      -0.698857                   0             0.241578
# 1                1       0.285342                   0            -0.824492
# 2                2       0.270383                   0             0.594952
# 3                3      -0.418744                   0             0.745673
# 4                4      -0.093789                   0            -1.546767
# ..             ...            ...                 ...                  ...
# 195            195      -0.182525                   0            -0.709333
# 196            196      -0.143619                   0             0.510025
# 197            197      -0.698934                   0            -0.312840
# 198            198      -0.472975                   0            -0.004061
# 199            199      -1.060584                   0            -0.129576
#
#      phenotype
# 0    -0.457280
# 1    -0.539151
# 2     0.865335
# 3     0.326929
# 4    -1.640556
# ..         ...
# 195  -0.891858
# 196   0.366406
# 197  -1.011774
# 198  -0.477036
# 199  -1.190160
#
# [200 rows x 5 columns]

# %%
input_effects_dict = {
    1:  0.50,   # mutation 2 has effect +0.5
    11: -0.30,  # mutation 10 has effect -0.3
    50:  0.10   # mutation 50 has effect +0.1
}
df = sim_phenotypes_custom(
    grg_1,
    input_effects=input_effects_dict,  # or beta_list, or input_effects_df
    heritability=0.7,
    standardized= True
)
# Out:
# The initial effect sizes are
#    mutation_id  effect_size  causal_mutation_id
# 0            1          0.5                   0
# 1           11         -0.3                   0
# 2           50          0.1                   0
# The genetic values of the individuals are
#      individual_id  genetic_value  causal_mutation_id
# 0                0      -0.061468                   0
# 1                1      -0.061468                   0
# 2                2      -0.061468                   0
# 3                3      -0.061468                   0
# 4                4      -0.061468                   0
# ..             ...            ...                 ...
# 195            195      -0.061468                   0
# 196            196       4.036411                   0
# 197            197      -0.061468                   0
# 198            198      -0.061468                   0
# 199            199      -0.061468                   0
#
# [200 rows x 3 columns]
