# %%
import numpy as np
import pygrgl
import matplotlib.pyplot as plt 

from grg_pheno_sim.phenotype import sim_phenotypes

# %%
# %%script bash --out /dev/null
# if [ ! -f test-200-samples.grg ]; then
#   grg construct -p 10 -t 2 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg
# fi

# %%
grg_1 = pygrgl.load_immutable_grg("test-200-samples.grg") #loading in a sample grg stored in the same directory

heritability = 0.33

phenotypes_standardized_genes = sim_phenotypes(grg_1, heritability=heritability, standardized=True)
# Out:
# The initial effect sizes are
#      mutation_id  effect_size  causal_mutation_id
# 0             43    -0.043778                   0
# 1             49    -0.004024                   0
# 2             54    -0.005199                   0
# 3             55     0.020529                   0
# 4             67     0.000948                   0
# ..           ...          ...                 ...
# 995        10798     0.001852                   0
# 996        10804     0.018198                   0
# 997        10844    -0.007695                   0
# 998        10860    -0.022206                   0
# 999        10888    -0.018921                   0
#
# [1000 rows x 3 columns]
# The genetic values of the individuals are
#      individual_id  genetic_value  causal_mutation_id
# 0                0      -0.786245                   0
# 1                1       0.197954                   0
# 2                2       0.182995                   0
# 3                3      -0.506132                   0
# 4                4      -0.181177                   0
# ..             ...            ...                 ...
# 195            195      -0.269912                   0
# 196            196      -0.231007                   0
# 197            197      -0.786322                   0
# 198            198      -0.560363                   0
# 199            199      -1.147972                   0
#
# [200 rows x 3 columns]

# %%
phenotypes_standardized_genes
# Out:
#      individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                0      -0.786245                   0             0.241578
# 1                1       0.197954                   0            -0.824492
# 2                2       0.182995                   0             0.594952
# 3                3      -0.506132                   0             0.745673
# 4                4      -0.181177                   0            -1.546767
# ..             ...            ...                 ...                  ...
# 195            195      -0.269912                   0            -0.709333
# 196            196      -0.231007                   0             0.510025
# 197            197      -0.786322                   0            -0.312840
# 198            198      -0.560363                   0            -0.004061
# 199            199      -1.147972                   0            -0.129576
#
#      phenotype
# 0    -0.544667
# 1    -0.626538
# 2     0.777947
# 3     0.239541
# 4    -1.727944
# ..         ...
# 195  -0.979246
# 196   0.279018
# 197  -1.099162
# 198  -0.564423
# 199  -1.277548
#
# [200 rows x 5 columns]
