# %%
import numpy as np
import pygrgl
import matplotlib.pyplot as plt 

from grg_pheno_sim.phenotype import sim_phenotypes, sim_phenotypes_StdOp

# %%
# %%script bash --out /dev/null
# if [ ! -f test-200-samples.grg ]; then
#   grg construct -p 10 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg
# fi
# Out:
# Building genotype hash index...
# ** Hashing input took 37 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 94 ms
# Wrote GRG to test-200-samples.vcf.gz.part0.tree0.grg in 1 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 63 ms
# Wrote GRG to test-200-samples.vcf.gz.part0.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took134 ms
# Wrote GRG to test-200-samples.vcf.gz.part0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 34 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 59 ms
# Wrote GRG to test-200-samples.vcf.gz.part1.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 61 ms
# Wrote GRG to test-200-samples.vcf.gz.part1.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took166 ms
# Wrote GRG to test-200-samples.vcf.gz.part1.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 34 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 61 ms
# Wrote GRG to test-200-samples.vcf.gz.part2.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 61 ms
# Wrote GRG to test-200-samples.vcf.gz.part2.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took204 ms
# Wrote GRG to test-200-samples.vcf.gz.part2.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 51 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 86 ms
# Wrote GRG to test-200-samples.vcf.gz.part3.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 38 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 74 ms
# Wrote GRG to test-200-samples.vcf.gz.part3.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took220 ms
# Wrote GRG to test-200-samples.vcf.gz.part3.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 63 ms
# Wrote GRG to test-200-samples.vcf.gz.part4.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 36 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 65 ms
# Wrote GRG to test-200-samples.vcf.gz.part4.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took229 ms
# Wrote GRG to test-200-samples.vcf.gz.part4.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 64 ms
# Wrote GRG to test-200-samples.vcf.gz.part5.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 65 ms
# Wrote GRG to test-200-samples.vcf.gz.part5.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took237 ms
# Wrote GRG to test-200-samples.vcf.gz.part5.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 64 ms
# Wrote GRG to test-200-samples.vcf.gz.part6.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 33 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 58 ms
# Wrote GRG to test-200-samples.vcf.gz.part6.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took168 ms
# Wrote GRG to test-200-samples.vcf.gz.part6.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 36 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 64 ms
# Wrote GRG to test-200-samples.vcf.gz.part7.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 63 ms
# Wrote GRG to test-200-samples.vcf.gz.part7.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took228 ms
# Wrote GRG to test-200-samples.vcf.gz.part7.grg in 1 ms
# Building genotype hash index...
# ** Hashing input took 34 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 61 ms
# Wrote GRG to test-200-samples.vcf.gz.part8.tree0.grg in 2 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 59 ms
# Wrote GRG to test-200-samples.vcf.gz.part8.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took171 ms
# Wrote GRG to test-200-samples.vcf.gz.part8.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 66 ms
# Wrote GRG to test-200-samples.vcf.gz.part9.tree0.grg in 0 ms
# Building genotype hash index...
# ** Hashing input took 35 ms
# Done
# Adding GRG shape from genotype hashes...
# Done
# Construction took 62 ms
# Wrote GRG to test-200-samples.vcf.gz.part9.tree1.grg in 0 ms
# Construction took 0 ms
# Mapping mutations took237 ms
# Wrote GRG to test-200-samples.vcf.gz.part9.grg in 0 ms

# %%
grg_1 = pygrgl.load_immutable_grg("test-200-samples.grg") #loading in a sample grg stored in the same directory

heritability = 0.33

phenotypes_standardized_genes = sim_phenotypes(grg_1, heritability=heritability, standardized=True)
# Out:
# The initial effect sizes are
#      mutation_id  effect_size  causal_mutation_id
# 0             43    -0.043778                   0
# 1             49    -0.004024                   0
# 2             54    -0.005199                   0
# 3             55     0.020529                   0
# 4             67     0.000948                   0
# ..           ...          ...                 ...
# 995        10798     0.001852                   0
# 996        10804     0.018198                   0
# 997        10844    -0.007695                   0
# 998        10860    -0.022206                   0
# 999        10888    -0.018921                   0
#
# [1000 rows x 3 columns]
# The genetic values of the individuals are
#      individual_id  genetic_value  causal_mutation_id
# 0                0      -0.698857                   0
# 1                1       0.285342                   0
# 2                2       0.270383                   0
# 3                3      -0.418744                   0
# 4                4      -0.093789                   0
# ..             ...            ...                 ...
# 195            195      -0.182525                   0
# 196            196      -0.143619                   0
# 197            197      -0.698934                   0
# 198            198      -0.472975                   0
# 199            199      -1.060584                   0
#
# [200 rows x 3 columns]

# %%
phenotypes_standardized_genes
# Out:
#      individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                0      -0.698857                   0             0.241578
# 1                1       0.285342                   0            -0.824492
# 2                2       0.270383                   0             0.594952
# 3                3      -0.418744                   0             0.745673
# 4                4      -0.093789                   0            -1.546767
# ..             ...            ...                 ...                  ...
# 195            195      -0.182525                   0            -0.709333
# 196            196      -0.143619                   0             0.510025
# 197            197      -0.698934                   0            -0.312840
# 198            198      -0.472975                   0            -0.004061
# 199            199      -1.060584                   0            -0.129576
#
#      phenotype
# 0    -0.457280
# 1    -0.539151
# 2     0.865335
# 3     0.326929
# 4    -1.640556
# ..         ...
# 195  -0.891858
# 196   0.366406
# 197  -1.011774
# 198  -0.477036
# 199  -1.190160
#
# [200 rows x 5 columns]

# %%
from grg_pheno_sim.phenotype import sim_phenotypes_custom
input_effects_dict = {
    1:  0.50,   # mutation 2 has effect +0.5
    11: -0.30,  # mutation 10 has effect -0.3
    50:  0.10   # mutation 50 has effect +0.1
}
df = sim_phenotypes_custom(
    grg_1,
    input_effects=input_effects_dict,  # or beta_list, or input_effects_df
    heritability=0.7,
    standardized= True
)
# Out:
# The initial effect sizes are
#    mutation_id  effect_size  causal_mutation_id
# 0            1          0.5                   0
# 1           11         -0.3                   0
# 2           50          0.1                   0
# The genetic values of the individuals are
#      individual_id  genetic_value  causal_mutation_id
# 0                0      -0.061468                   0
# 1                1      -0.061468                   0
# 2                2      -0.061468                   0
# 3                3      -0.061468                   0
# 4                4      -0.061468                   0
# ..             ...            ...                 ...
# 195            195      -0.061468                   0
# 196            196       4.036411                   0
# 197            197      -0.061468                   0
# 198            198      -0.061468                   0
# 199            199      -0.061468                   0
#
# [200 rows x 3 columns]
