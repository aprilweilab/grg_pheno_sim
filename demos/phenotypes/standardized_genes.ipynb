# %%
import numpy as np
import pygrgl
import matplotlib.pyplot as plt 

from grg_pheno_sim.phenotype import sim_phenotypes, sim_phenotypes_StdOp

# %%
# %%script bash --out /dev/null
# if [ ! -f test-200-samples.grg ]; then
#   grg construct -p 10 -t 2 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg
# fi
# Out:
# Traceback (most recent call last):
#   File "/home/chris/pygrgl-env/bin/grg", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/chris/pygrgl-env/lib/python3.12/site-packages/pygrgl/cli.py", line 64, in main
#     construct.from_tabular(args)
#   File "/home/chris/pygrgl-env/lib/python3.12/site-packages/pygrgl/clicmd/construct.py", line 235, in from_tabular
#     verify_file(args.input_file)
#   File "/home/chris/pygrgl-env/lib/python3.12/site-packages/pygrgl/clicmd/construct.py", line 233, in verify_file
#     raise RuntimeError(f"File not found: {fn}")
# RuntimeError: File not found: ../data/test-200-samples.vcf.gz
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('script', 'bash --out /dev/null', 'if [ ! -f test-200-samples.grg ]; then\n  grg construct -p 10 -t 2 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg\nfi\n')
#
# File ~/pygrgl-env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2547, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2545 with self.builtin_trap:
#    2546     args = (magic_arg_s, cell)
# -> 2547     result = fn(*args, **kwargs)
#    2549 # The code below prevents the output from being displayed
#    2550 # when using magics with decorator @output_can_be_silenced
#    2551 # when the last Python token in the expression is a ';'.
#    2552 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/pygrgl-env/lib/python3.12/site-packages/IPython/core/magics/script.py:336, in ScriptMagics.shebang(self, line, cell)
#     331 if args.raise_error and p.returncode != 0:
#     332     # If we get here and p.returncode is still None, we must have
#     333     # killed it but not yet seen its return code. We don't wait for it,
#     334     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     335     rc = p.returncode or -9
# --> 336     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'if [ ! -f test-200-samples.grg ]; then\n  grg construct -p 10 -t 2 ../data/test-200-samples.vcf.gz --out-file test-200-samples.grg\nfi\n'' returned non-zero exit status 1.

# %%
import time 
grg_1 = pygrgl.load_immutable_grg("/home/chris/PhenoSim/grg_pheno_sim/demos/phenotypes/simulation-source-100000-100000000.igd.final copy.grg") #loading in a sample grg stored in the same directory

heritability = 0.33
phenotypes_standardized_genes = sim_phenotypes(grg_1, heritability=heritability, standardized=True)

standOp = sim_phenotypes_StdOp(grg_1, heritability=heritability)
print(standOp)
# Out:
# The initial effect sizes are
#      mutation_id  effect_size  causal_mutation_id
# 0           2243    -0.038102                   0
# 1           2505    -0.001788                   0
# 2           2716    -0.015772                   0
# 3           2781     0.002985                   0
# 4           2804     0.015298                   0
# ..           ...          ...                 ...
# 995       509631     0.008351                   0
# 996       510442     0.009957                   0
# 997       510752     0.015359                   0
# 998       510853     0.018619                   0
# 999       511823    -0.003346                   0
#
# [1000 rows x 3 columns]
# The genetic values of the individuals are
#        individual_id  genetic_value  causal_mutation_id
# 0                  0      -0.022254                   0
# 1                  1      -0.385680                   0
# 2                  2       0.264554                   0
# 3                  3      -0.299677                   0
# 4                  4       0.205757                   0
# ...              ...            ...                 ...
# 99995          99995      -0.174924                   0
# 99996          99996       0.179616                   0
# 99997          99997       0.408779                   0
# 99998          99998       1.133941                   0
# 99999          99999      -1.415652                   0
#
# [100000 rows x 3 columns]
# Ops raw genetic mult 0 -1.370219522786416
# Ops adj  [-1.34796583]
#        individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                  0      -0.022254                   0             0.256742
# 1                  1      -0.385680                   0            -0.876246
# 2                  2       0.264554                   0             0.632298
# 3                  3      -0.299677                   0             0.792479
# 4                  4       0.205757                   0            -1.643859
# ...              ...            ...                 ...                  ...
# 99995          99995      -0.174924                   0             0.838927
# 99996          99996       0.179616                   0             0.620769
# 99997          99997       0.408779                   0             1.266512
# 99998          99998       1.133941                   0            -0.129135
# 99999          99999      -1.415652                   0             0.551530
#
#        phenotype
# 0       0.234488
# 1      -1.261926
# 2       0.896852
# 3       0.492803
# 4      -1.438101
# ...          ...
# 99995   0.664003
# 99996   0.800384
# 99997   1.675291
# 99998   1.004805
# 99999  -0.864122
#
# [100000 rows x 5 columns]

# %%
phenotypes_standardized_genes
# Out:
#        individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                  0      -0.022254                   0             0.256742
# 1                  1      -0.385680                   0            -0.876246
# 2                  2       0.264554                   0             0.632298
# 3                  3      -0.299677                   0             0.792479
# 4                  4       0.205757                   0            -1.643859
# ...              ...            ...                 ...                  ...
# 99995          99995      -0.174924                   0             0.838927
# 99996          99996       0.179616                   0             0.620769
# 99997          99997       0.408779                   0             1.266512
# 99998          99998       1.133941                   0            -0.129135
# 99999          99999      -1.415652                   0             0.551530
#
#        phenotype
# 0       0.234488
# 1      -1.261926
# 2       0.896852
# 3       0.492803
# 4      -1.438101
# ...          ...
# 99995   0.664003
# 99996   0.800384
# 99997   1.675291
# 99998   1.004805
# 99999  -0.864122
#
# [100000 rows x 5 columns]

# %%
standOp
# Out:
#        individual_id  genetic_value  causal_mutation_id  environmental_noise  \
# 0                  0      -0.022254                   0             0.256742
# 1                  1      -0.385680                   0            -0.876246
# 2                  2       0.264554                   0             0.632298
# 3                  3      -0.299677                   0             0.792479
# 4                  4       0.205757                   0            -1.643859
# ...              ...            ...                 ...                  ...
# 99995          99995      -0.174924                   0             0.838927
# 99996          99996       0.179616                   0             0.620769
# 99997          99997       0.408779                   0             1.266512
# 99998          99998       1.133941                   0            -0.129135
# 99999          99999      -1.415652                   0             0.551530
#
#        phenotype
# 0       0.234488
# 1      -1.261926
# 2       0.896852
# 3       0.492803
# 4      -1.438101
# ...          ...
# 99995   0.664003
# 99996   0.800384
# 99997   1.675291
# 99998   1.004805
# 99999  -0.864122
#
# [100000 rows x 5 columns]
